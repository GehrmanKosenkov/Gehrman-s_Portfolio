# %% [markdown]
# Agricultural Analysis Part 2: Python
# By Gehrman Kosenkov
#
#
#
# -----------PROJECT DESCRIPTION-----------
#
# DISCLAIMER
#
# Beware that even though the project results were shared with one of my previous employers, namely AlmaStone*, this file mainly aims to demonstrate my data analysis skills rather than provide commercially valuable insights.
#
# AlmaStone* is a UK based commodity trade finance fund focused on emerging markets.
#
# OVERALL PROJECT OBJECTIVES:
#
# 1) Reveal relevant countries which agricultural sectors have great potential for investment
# 2) Analyze certain factors that might presumably affect agricultural production of those countries.
#
# PROJECT STRUCTURE
#
# The project was divided into two parts: Part 1 -SQL and Part 2 -Python.
#
# This file describes Part-2 Python. Link to Part-1 SQL can be found in my portfolio.

# %% [markdown]
# -----------AGRICULTURAL ANALYSIS PART 2: PYTHON-----------
#
# STAGES
#
# 1.Import Of The Table "Grains_Pulses_Meals_USDA" Produced In MySQL
# 2.Grains_Pulses_Meals_USDA:Data Exploration,Cleaning And Organization
# 3.Grains_Pulses_Meals_USDA: Analysis Of Key Corn Exporters
# 4.Importing Table "Fertilizer_Use_USA" containing data on annual fertilizer use in USA
# 5.Fertilizer_Use_USA: Data Exploration, Cleaning And Organization
# 6.Combining Fertilizer_Use_USA With Grains_Pulses_Meals_USDA into New_Grains_Pulses_Meals_USDA
# 7.New_Grains_Pulses_Meals_USDA: Statistical Analysis, Multiple Linear Regression, Scatter Plots, Pearson Coefficient
# 8.Conclusions
#
#
# DATA SOURCES
#
# -Table "Grains_Pulses_Meals_USDA" Produced In MySQL In Part 1 Of This Project
# -Table "Fertilizer_Use_USA" downloaded from USDA website
#
# SKILLS USED:
#
# Pandas, Numpy, Seaborn, Matplotlib, Scipy, Sklearn, Statistical Analysis, Multiple Linear Regression, Scatter Plots, Pearson Coefficient

# %% [markdown]
# 1.Import Of "Grains_Pulses_Meals_USDA"

# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %%
Grains_Pulses_Meals_USDA = pd.read_csv('/Users/germankosenkov/Desktop/work:domestic/Data Analysis Projects Chosen/Python/Grains_Pulses_Meals_USDA.csv',sep=',',)
# Out:
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/1613126619.py:1: DtypeWarning: Columns (10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   Grains_Pulses_Meals_USDA = pd.read_csv('/Users/germankosenkov/Desktop/work:domestic/Data Analysis Projects Chosen/Python/Grains_Pulses_Meals_USDA.csv',sep=',',)

# %%
Grains_Pulses_Meals_USDA

#The number of rows and columns matches the SQL table which means the import went smoothly.
# Out:
#         Commodity_Code Commodity_Description Country_Code Country_Name  \
# 0               813700           Meal, Copra           AS    Australia
# 1               813700           Meal, Copra           AS    Australia
# 2               813700           Meal, Copra           AS    Australia
# 3               813700           Meal, Copra           AS    Australia
# 4               813700           Meal, Copra           AS    Australia
# ...                ...                   ...          ...          ...
# 289185          422110          Rice, Milled           JM      Jamaica
# 289186          422110          Rice, Milled           JM      Jamaica
# 289187          422110          Rice, Milled           JM      Jamaica
# 289188          422110          Rice, Milled           JM      Jamaica
# 289189          422110          Rice, Milled           JM      Jamaica
#
#         Market_Year  Month  Attribute_ID Attribute_Description  Unit_ID  \
# 0              1964      6            20      Beginning Stocks        8
# 1              1964      6           125  Domestic Consumption        8
# 2              1964      6           176         Ending Stocks        8
# 3              1964      6            88               Exports        8
# 4              1964      6            57               Imports        8
# ...             ...    ...           ...                   ...      ...
# 289185         2013      5            28            Production        8
# 289186         2013      5           178    Total Distribution        8
# 289187         2013      5            86          Total Supply        8
# 289188         2014      5            20      Beginning Stocks        8
# 289189         2014      5           125  Domestic Consumption        8
#
#         Volume Unit_Description  Average_Production_2000_2022  \
# 0            0               MT                           NaN
# 1        11000               MT                           NaN
# 2            0               MT                           NaN
# 3            0               MT                           NaN
# 4            0               MT                           NaN
# ...        ...              ...                           ...
# 289185       0              NaN                           NaN
# 289186   82000              NaN                           NaN
# 289187   82000              NaN                           NaN
# 289188       0              NaN                           NaN
# 289189   89000              NaN                           NaN
#
#        Above_Or_Below_Average  Annual_Precipitation
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
# ...                       ...                   ...
# 289185                    NaN                   NaN
# 289186                    NaN                   NaN
# 289187                    NaN                   NaN
# 289188                    NaN                   NaN
# 289189                    NaN                   NaN
#
# [289190 rows x 14 columns]

# %% [markdown]
# 2.Grains_Pulses_Meals_USDA:Data Exploration,Cleaning And Organization

# %%
# Checking datatypes

Grains_Pulses_Meals_USDA.dtypes

#Looks like evertything is correct
# Out:
# Commodity_Code                    int64
# Commodity_Description            object
# Country_Code                     object
# Country_Name                     object
# Market_Year                       int64
# Month                             int64
# Attribute_ID                      int64
# Attribute_Description            object
# Unit_ID                           int64
# Volume                            int64
# Unit_Description                 object
# Average_Production_2000_2022    float64
# Above_Or_Below_Average           object
# Annual_Precipitation            float64
# dtype: object

# %%
Grains_Pulses_Meals_USDA.describe(include='all')
# Out:
#         Commodity_Code Commodity_Description Country_Code Country_Name  \
# count    289190.000000                289190       289110       289190
# unique             NaN                    15          175          177
# top                NaN                  Corn           CH        China
# freq               NaN                 54528         5208         5208
# mean     618340.866379                   NaN          NaN          NaN
# std      186931.369591                   NaN          NaN          NaN
# min      422110.000000                   NaN          NaN          NaN
# 25%      440000.000000                   NaN          NaN          NaN
# 50%      459100.000000                   NaN          NaN          NaN
# 75%      813300.000000                   NaN          NaN          NaN
# max      814200.000000                   NaN          NaN          NaN
#
#           Market_Year          Month   Attribute_ID Attribute_Description  \
# count   289190.000000  289190.000000  289190.000000                289190
# unique            NaN            NaN            NaN                     8
# top               NaN            NaN            NaN      Beginning Stocks
# freq              NaN            NaN            NaN                 36150
# mean      1992.180753       6.283931      94.749950                   NaN
# std         16.716614       2.061931      57.049971                   NaN
# min       1960.000000       1.000000      20.000000                   NaN
# 25%       1978.000000       5.000000      35.250000                   NaN
# 50%       1992.000000       6.000000      88.000000                   NaN
# 75%       2007.000000       7.000000     125.000000                   NaN
# max       2021.000000      12.000000     178.000000                   NaN
#
#          Unit_ID        Volume Unit_Description  Average_Production_2000_2022  \
# count   289190.0  2.891900e+05           138228                  1.341200e+04
# unique       NaN           NaN                1                           NaN
# top          NaN           NaN               MT                           NaN
# freq         NaN           NaN           138228                           NaN
# mean         8.0  1.333559e+06              NaN                  1.212406e+06
# std          0.0  1.096788e+07              NaN                  5.226408e+06
# min          8.0  0.000000e+00              NaN                  0.000000e+00
# 25%          8.0  0.000000e+00              NaN                  1.272700e+04
# 50%          8.0  2.500000e+04              NaN                  5.450000e+04
# 75%          8.0  2.260000e+05              NaN                  2.870450e+05
# max          8.0  4.855440e+08              NaN                  4.601977e+07
#
#        Above_Or_Below_Average  Annual_Precipitation
# count                    6619            477.000000
# unique                      3                   NaN
# top             BELOW AVERAGE                   NaN
# freq                     2881                   NaN
# mean                      NaN             30.880503
# std                       NaN              2.187718
# min                       NaN             26.000000
# 25%                       NaN             30.000000
# 50%                       NaN             31.000000
# 75%                       NaN             32.000000
# max                       NaN             35.000000

# %%
#Using subsetting to select only the columns needed for the analysis

Grains_Pulses_Meals_USDA = Grains_Pulses_Meals_USDA[[
 #'Commodity_Code',
 'Commodity_Description', 
 #'Country_Code',
 'Country_Name', 
 'Market_Year',
 #Month,
#'Attribute_ID',
'Attribute_Description', 
#Unit_ID,
'Volume',
#'Unit_Description',
'Average_Production_2000_2022', 
'Above_Or_Below_Average',
'Annual_Precipitation']].copy()

# %%
Grains_Pulses_Meals_USDA.columns
# Out:
# Index(['Commodity_Description', 'Country_Name', 'Market_Year',
#        'Attribute_Description', 'Volume', 'Average_Production_2000_2022',
#        'Above_Or_Below_Average', 'Annual_Precipitation'],
#       dtype='object')

# %%
#Checking if there is any unexpected missing data

Grains_Pulses_Meals_USDA.isna().sum()

#Missing data was expected for Unit_Description, Average_Production_2000_2022, Above_Or_Below_Average, Annual_Precipitation (see Part 1 - SQL)
# Out:
# Commodity_Description                0
# Country_Name                         0
# Market_Year                          0
# Attribute_Description                0
# Volume                               0
# Average_Production_2000_2022    275778
# Above_Or_Below_Average          282571
# Annual_Precipitation            288713
# dtype: int64

# %%
#Checking for duplicated rows 

Grains_Pulses_Meals_USDA.loc[Grains_Pulses_Meals_USDA.duplicated()]

#No duplicated rows discovered
# Out:
# Empty DataFrame
# Columns: [Commodity_Description, Country_Name, Market_Year, Attribute_Description, Volume, Average_Production_2000_2022, Above_Or_Below_Average, Annual_Precipitation]
# Index: []

# %%
#Checking for duplicates focusing on a particular set of columns

Grains_Pulses_Meals_USDA.loc[Grains_Pulses_Meals_USDA.duplicated(subset=['Commodity_Description', 'Country_Name', 'Market_Year','Attribute_Description', 'Volume'])]

#No duplicates discovered
# Out:
# Empty DataFrame
# Columns: [Commodity_Description, Country_Name, Market_Year, Attribute_Description, Volume, Average_Production_2000_2022, Above_Or_Below_Average, Annual_Precipitation]
# Index: []

# %% [markdown]
# 3.Grains_Pulses_Meals_USDA: Analysis Of Key Corn Exporters

# %%
#There was a request from a senior colleague of mine to explore key exporting coutnries for corn. 

#For this purpose, I created a new dataframe focusing on exports of corn in 2020.


Exports_Grains_Pulses_Meals_USDA = Grains_Pulses_Meals_USDA.loc[(Grains_Pulses_Meals_USDA['Market_Year'] == 2020) & (Grains_Pulses_Meals_USDA['Attribute_Description'] == 'Exports') & (Grains_Pulses_Meals_USDA['Commodity_Description'] == 'Corn')]


Exports_Grains_Pulses_Meals_USDA.head(10)
# Out:
#        Commodity_Description Country_Name  Market_Year Attribute_Description  \
# 168983                  Corn  Afghanistan         2020               Exports
# 169471                  Corn      Albania         2020               Exports
# 169959                  Corn      Algeria         2020               Exports
# 170439                  Corn       Angola         2020               Exports
# 170927                  Corn    Argentina         2020               Exports
# 171463                  Corn    Australia         2020               Exports
# 171735                  Corn   Azerbaijan         2020               Exports
# 171831                  Corn   Bangladesh         2020               Exports
# 172103                  Corn      Belarus         2020               Exports
# 172591                  Corn        Benin         2020               Exports
#
#           Volume  Average_Production_2000_2022 Above_Or_Below_Average  \
# 168983         0                           NaN                    NaN
# 169471         0                           NaN                    NaN
# 169959         0                           NaN                    NaN
# 170439         0                           NaN                    NaN
# 170927  34000000                           NaN                    NaN
# 171463     50000                           NaN                    NaN
# 171735         0                           NaN                    NaN
# 171831    200000                           NaN                    NaN
# 172103     50000                           NaN                    NaN
# 172591         0                           NaN                    NaN
#
#         Annual_Precipitation
# 168983                   NaN
# 169471                   NaN
# 169959                   NaN
# 170439                   NaN
# 170927                   NaN
# 171463                   NaN
# 171735                   NaN
# 171831                   NaN
# 172103                   NaN
# 172591                   NaN

# %%
pd.set_option('display.max_rows', 150)

# %%
#Applying binning to reveal the leading corn exporters in 2020 

bins = np.linspace(min(Exports_Grains_Pulses_Meals_USDA['Volume']),max(Exports_Grains_Pulses_Meals_USDA['Volume']),4)

group_names = ["Low","Medium","High"]

Exports_Grains_Pulses_Meals_USDA["Volumes-Binned"] = pd.cut(Exports_Grains_Pulses_Meals_USDA["Volume"],bins,labels=group_names,include_lowest=True)

Exports_Grains_Pulses_Meals_USDA.sort_values(by=['Volumes-Binned'], ascending=False).head(10)
# Out:
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/2309766510.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Exports_Grains_Pulses_Meals_USDA["Volumes-Binned"] = pd.cut(Exports_Grains_Pulses_Meals_USDA["Volume"],bins,labels=group_names,include_lowest=True)
#        Commodity_Description     Country_Name  Market_Year  \
# 219919                  Corn    United States         2020
# 219215                  Corn          Ukraine         2020
# 170927                  Corn        Argentina         2020
# 174607                  Corn           Brazil         2020
# 204479                  Corn            Nepal         2020
# 204967                  Corn      New Zealand         2020
# 205455                  Corn        Nicaragua         2020
# 205943                  Corn          Nigeria         2020
# 206175                  Corn  North Macedonia         2020
# 168983                  Corn      Afghanistan         2020
#
#        Attribute_Description    Volume  Average_Production_2000_2022  \
# 219919               Exports  66043000                           NaN
# 219215               Exports  24000000                           NaN
# 170927               Exports  34000000                           NaN
# 174607               Exports  39000000                           NaN
# 204479               Exports         0                           NaN
# 204967               Exports      3000                           NaN
# 205455               Exports      5000                           NaN
# 205943               Exports    100000                           NaN
# 206175               Exports     15000                           NaN
# 168983               Exports         0                           NaN
#
#        Above_Or_Below_Average  Annual_Precipitation Volumes-Binned
# 219919                    NaN                   NaN           High
# 219215                    NaN                   NaN         Medium
# 170927                    NaN                   NaN         Medium
# 174607                    NaN                   NaN         Medium
# 204479                    NaN                   NaN            Low
# 204967                    NaN                   NaN            Low
# 205455                    NaN                   NaN            Low
# 205943                    NaN                   NaN            Low
# 206175                    NaN                   NaN            Low
# 168983                    NaN                   NaN            Low

# %%
#Creating a list of leading corn exporters for 2020. The list would come in handy later.  

filt = (Exports_Grains_Pulses_Meals_USDA['Volumes-Binned']=='High') | (Exports_Grains_Pulses_Meals_USDA['Volumes-Binned']=='Medium')

Export_Leaders = Exports_Grains_Pulses_Meals_USDA.loc[filt]['Country_Name'].to_list()
print(Export_Leaders)
# Out:
# ['Argentina', 'Brazil', 'Ukraine', 'United States']

# %%
#Calculating % occupied by Export_Leaders in the global production. 

Production_Grains_Pulses_Meals_USDA = Grains_Pulses_Meals_USDA.loc[(Grains_Pulses_Meals_USDA['Market_Year'] == 2020) & (Grains_Pulses_Meals_USDA['Attribute_Description'] == 'Production') & (Grains_Pulses_Meals_USDA['Commodity_Description'] == 'Corn')]

Production_Grains_Pulses_Meals_USDA.head(10)
# Out:
#        Commodity_Description Country_Name  Market_Year Attribute_Description  \
# 168985                  Corn  Afghanistan         2020            Production
# 169473                  Corn      Albania         2020            Production
# 169961                  Corn      Algeria         2020            Production
# 170441                  Corn       Angola         2020            Production
# 170929                  Corn    Argentina         2020            Production
# 171465                  Corn    Australia         2020            Production
# 171737                  Corn   Azerbaijan         2020            Production
# 171833                  Corn   Bangladesh         2020            Production
# 172105                  Corn      Belarus         2020            Production
# 172593                  Corn        Benin         2020            Production
#
#           Volume  Average_Production_2000_2022 Above_Or_Below_Average  \
# 168985    230000                           NaN                    NaN
# 169473    375000                           NaN                    NaN
# 169961      1000                           NaN                    NaN
# 170441   2100000                           NaN                    NaN
# 170929  47500000                           NaN                    NaN
# 171465    370000                           NaN                    NaN
# 171737    285000                           NaN                    NaN
# 171833   4600000                           NaN                    NaN
# 172105   1200000                           NaN                    NaN
# 172593   1500000                           NaN                    NaN
#
#         Annual_Precipitation
# 168985                   NaN
# 169473                   NaN
# 169961                   NaN
# 170441                   NaN
# 170929                   NaN
# 171465                   NaN
# 171737                   NaN
# 171833                   NaN
# 172105                   NaN
# 172593                   NaN

# %%
#Calculating % occupied by Export_Leaders in the global production.

Sum = Production_Grains_Pulses_Meals_USDA['Volume'].sum()

Production_Grains_Pulses_Meals_USDA['Share_In_Global_Production'] = (Production_Grains_Pulses_Meals_USDA['Volume'].divide(other = Sum))*100

Filt = Production_Grains_Pulses_Meals_USDA['Country_Name'].isin(Export_Leaders)

Share_of_Export_Leaders_Production = Production_Grains_Pulses_Meals_USDA.loc[Filt]['Share_In_Global_Production'].sum().round(decimals = 1)

print('{}%'.format(Share_of_Export_Leaders_Production ))
# Out:
# 48.1%
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/4068901704.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Production_Grains_Pulses_Meals_USDA['Share_In_Global_Production'] = (Production_Grains_Pulses_Meals_USDA['Volume'].divide(other = Sum))*100

# %%
#It would be interesting to compare the % of global production by Export_Leaders with their % of global exports and consumption 

Exports_Grains_Pulses_Meals_USDA = Grains_Pulses_Meals_USDA.loc[(Grains_Pulses_Meals_USDA['Market_Year'] == 2020) & (Grains_Pulses_Meals_USDA['Attribute_Description'] == 'Exports') & (Grains_Pulses_Meals_USDA['Commodity_Description'] == 'Corn')]

Exports_Grains_Pulses_Meals_USDA.head(10)
# Out:
#        Commodity_Description Country_Name  Market_Year Attribute_Description  \
# 168983                  Corn  Afghanistan         2020               Exports
# 169471                  Corn      Albania         2020               Exports
# 169959                  Corn      Algeria         2020               Exports
# 170439                  Corn       Angola         2020               Exports
# 170927                  Corn    Argentina         2020               Exports
# 171463                  Corn    Australia         2020               Exports
# 171735                  Corn   Azerbaijan         2020               Exports
# 171831                  Corn   Bangladesh         2020               Exports
# 172103                  Corn      Belarus         2020               Exports
# 172591                  Corn        Benin         2020               Exports
#
#           Volume  Average_Production_2000_2022 Above_Or_Below_Average  \
# 168983         0                           NaN                    NaN
# 169471         0                           NaN                    NaN
# 169959         0                           NaN                    NaN
# 170439         0                           NaN                    NaN
# 170927  34000000                           NaN                    NaN
# 171463     50000                           NaN                    NaN
# 171735         0                           NaN                    NaN
# 171831    200000                           NaN                    NaN
# 172103     50000                           NaN                    NaN
# 172591         0                           NaN                    NaN
#
#         Annual_Precipitation
# 168983                   NaN
# 169471                   NaN
# 169959                   NaN
# 170439                   NaN
# 170927                   NaN
# 171463                   NaN
# 171735                   NaN
# 171831                   NaN
# 172103                   NaN
# 172591                   NaN

# %%
#Calculating % occupied by Export_Leaders in the global exports

Sum_Exports = Exports_Grains_Pulses_Meals_USDA['Volume'].sum()

Exports_Grains_Pulses_Meals_USDA['Share_In_Global_Exports'] = (Exports_Grains_Pulses_Meals_USDA['Volume'].divide(other = Sum_Exports))*100

Filt_Exports = Exports_Grains_Pulses_Meals_USDA['Country_Name'].isin(Export_Leaders)

Share_of_Export_Leaders_In_Exports = Exports_Grains_Pulses_Meals_USDA.loc[Filt_Exports]['Share_In_Global_Exports'].sum().round(decimals = 1) 

print('{}%'.format(Share_of_Export_Leaders_In_Exports))
# Out:
# 87.4%
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/2929788300.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Exports_Grains_Pulses_Meals_USDA['Share_In_Global_Exports'] = (Exports_Grains_Pulses_Meals_USDA['Volume'].divide(other = Sum_Exports))*100

# %%
#Calculating % occupied by Export_Leaders in the global consumption

Consumption_Grains_Pulses_Meals_USDA = Grains_Pulses_Meals_USDA.loc[(Grains_Pulses_Meals_USDA['Market_Year'] == 2020) & (Grains_Pulses_Meals_USDA['Attribute_Description'] == 'Domestic Consumption') & (Grains_Pulses_Meals_USDA['Commodity_Description'] == 'Corn')]

Consumption_Grains_Pulses_Meals_USDA.head(10)
# Out:
#        Commodity_Description Country_Name  Market_Year Attribute_Description  \
# 168981                  Corn  Afghanistan         2020  Domestic Consumption
# 169469                  Corn      Albania         2020  Domestic Consumption
# 169957                  Corn      Algeria         2020  Domestic Consumption
# 170437                  Corn       Angola         2020  Domestic Consumption
# 170925                  Corn    Argentina         2020  Domestic Consumption
# 171461                  Corn    Australia         2020  Domestic Consumption
# 171733                  Corn   Azerbaijan         2020  Domestic Consumption
# 171829                  Corn   Bangladesh         2020  Domestic Consumption
# 172101                  Corn      Belarus         2020  Domestic Consumption
# 172589                  Corn        Benin         2020  Domestic Consumption
#
#           Volume  Average_Production_2000_2022 Above_Or_Below_Average  \
# 168981    240000                           NaN                    NaN
# 169469    459000                           NaN                    NaN
# 169957   5200000                           NaN                    NaN
# 170437   2300000                           NaN                    NaN
# 170925  15000000                           NaN                    NaN
# 171461    310000                           NaN                    NaN
# 171733    350000                           NaN                    NaN
# 171829   6100000                           NaN                    NaN
# 172101   1250000                           NaN                    NaN
# 172589   1520000                           NaN                    NaN
#
#         Annual_Precipitation
# 168981                   NaN
# 169469                   NaN
# 169957                   NaN
# 170437                   NaN
# 170925                   NaN
# 171461                   NaN
# 171733                   NaN
# 171829                   NaN
# 172101                   NaN
# 172589                   NaN

# %%
#Calculating % occupied by Export_Leaders in the global consumption

Sum_Consumtpion = Consumption_Grains_Pulses_Meals_USDA['Volume'].sum()

Consumption_Grains_Pulses_Meals_USDA['Share_In_Global_Consumption'] = (Consumption_Grains_Pulses_Meals_USDA['Volume'].divide(other = Sum_Consumtpion))*100

Filt_Consumption = Consumption_Grains_Pulses_Meals_USDA['Country_Name'].isin(Export_Leaders)

Share_of_Export_Leaders_In_Consumption = Consumption_Grains_Pulses_Meals_USDA.loc[Filt_Consumption]['Share_In_Global_Consumption'].sum().round(decimals = 1) 

print('{}%'.format(Share_of_Export_Leaders_In_Consumption))
# Out:
# 34.6%
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/458259506.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Consumption_Grains_Pulses_Meals_USDA['Share_In_Global_Consumption'] = (Consumption_Grains_Pulses_Meals_USDA['Volume'].divide(other = Sum_Consumtpion))*100

# %%
#For convenience, inserting all the data into a dataframe

Data = [[Share_of_Export_Leaders_Production,Share_of_Export_Leaders_In_Consumption, Share_of_Export_Leaders_In_Exports]]

Export_Leaders_Data = pd.DataFrame(Data, columns = ['% of Global Corn Production','% of Global Corn Consumption','% of Global Corn Exports'])

index = pd.Index(["Argentina, Brazil, Ukraine, United States"])

Export_Leaders_Data.set_index(index, inplace = True)

Export_Leaders_Data
# Out:
#                                            % of Global Corn Production  \
# Argentina, Brazil, Ukraine, United States                         48.1
#
#                                            % of Global Corn Consumption  \
# Argentina, Brazil, Ukraine, United States                          34.6
#
#                                            % of Global Corn Exports
# Argentina, Brazil, Ukraine, United States                      87.4

# %% [markdown]
# 4.Importing Table "Fertilizer_Use_USA"

# %%
#A senior colleague of mine requested me to add data on annual fertilizer use in USA. This data (along with annual precipitation) would be used as a predictor for corn production volumes in the US. 

#Importing the fertilizer fata 

xls = pd.ExcelFile('/Users/germankosenkov/Desktop/fertilizeruse.xls')

Fertilizer_Use_USA = pd.read_excel(xls, 'Table2')

Fertilizer_Use_USA.head(10)
# Out:
#       Unnamed: 0  Unnamed: 1  \
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6  United States  Production
# 7  United States  Production
# 8  United States  Production
# 9  United States  Production
#
#   Table 2. Estimated U.S. plant nutrient use by selected crops 1/  \
# 0                                                NaN
# 1                                                NaN
# 2                                Year ending June 30
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                               1964
# 7                                               1965
# 8                                               1966
# 9                                               1967
#
#                                           Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0                                                NaN         NaN        NaN
# 1                                           Nitrogen         NaN        NaN
# 2                                               Corn      Cotton   Soybeans
# 3                                                NaN         NaN        NaN
# 4    --------------------------------------------...         NaN        NaN
# 5                                                NaN         NaN        NaN
# 6                                         1622.53695  394.107714   15.54329
# 7                                           2150.643  452.802838   19.37485
# 8                                         2596.15811  330.352848   40.27752
# 9                                         3044.05368  268.746624  55.717935
#
#   Unnamed: 6   Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0        NaN          NaN         NaN         NaN         NaN         NaN
# 1        NaN          NaN   Phosphate         NaN         NaN         NaN
# 2      Wheat       Other         Corn      Cotton    Soybeans       Wheat
# 3        NaN          NaN         NaN         NaN         NaN         NaN
# 4        NaN          NaN         NaN         NaN         NaN         NaN
# 5        NaN          NaN         NaN         NaN         NaN         NaN
# 6  353.23884  1967.373206  1052.50977  210.813876     57.0978   270.56592
# 7  426.76584  1588.913472   1336.0055  229.621068    90.18112    326.9577
# 8   424.1832  1935.328322  1626.16497  167.919015   164.83948    328.9584
# 9   623.8736  2034.708161   1857.1716   145.52384  203.890905   462.77632
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  Unnamed: 17
# 0         NaN         NaN         NaN         NaN         NaN          NaN
# 1         NaN      Potash         NaN         NaN         NaN          NaN
# 2      Other         Corn      Cotton    Soybeans       Wheat       Other
# 3         NaN         NaN         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN         NaN         NaN          NaN
# 5         NaN         NaN         NaN         NaN         NaN          NaN
# 6        1787    829.3698         175    70.42062   151.42784         1503
# 7        1529  1204.36008  177.469842  116.777505  150.572625  1185.319948
# 8        1609   1512.7116   135.05967   183.48648  150.141375  1239.800875
# 9        1635   1750.4376    103.9456   231.44373   222.98016   1332.99291

# %% [markdown]
# 5.Fertilizer_Use_USA: Data Exploration, Cleaning And Organization

# %%
#Clearly, data needs exploration,cleaning and organization before being added to "Grains_Pulses_Meals_USDA"

Fertilizer_Use_USA = Fertilizer_Use_USA.rename(columns={'Unnamed: 0':'Country_Name', 'Unnamed: 1':'Attribute_Description','Table 2. Estimated U.S. plant nutrient use by selected crops 1/': 'Market_Year','Unnamed: 3':'Nitrogen_Use (1,000 nutrient short tons)','Unnamed: 8':'Phosphate_Use (1,000 nutrient short tons)','Unnamed: 13':'Potash_Use (1,000 nutrient short tons)'})

Fertilizer_Use_USA= Fertilizer_Use_USA[['Country_Name','Attribute_Description', 'Market_Year', 'Nitrogen_Use (1,000 nutrient short tons)', 'Phosphate_Use (1,000 nutrient short tons)','Potash_Use (1,000 nutrient short tons)']].copy()                          

Fertilizer_Use_USA
# Out:
#      Country_Name Attribute_Description  \
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2             NaN                   NaN
# 3             NaN                   NaN
# 4             NaN                   NaN
# 5             NaN                   NaN
# 6   United States            Production
# 7   United States            Production
# 8   United States            Production
# 9   United States            Production
# 10  United States            Production
# 11  United States            Production
# 12  United States            Production
# 13  United States            Production
# 14  United States            Production
# 15  United States            Production
# 16  United States            Production
# 17  United States            Production
# 18  United States            Production
# 19  United States            Production
# 20  United States            Production
# 21  United States            Production
# 22  United States            Production
# 23  United States            Production
# 24  United States            Production
# 25  United States            Production
# 26  United States            Production
# 27  United States            Production
# 28  United States            Production
# 29  United States            Production
# 30  United States            Production
# 31  United States            Production
# 32  United States            Production
# 33  United States            Production
# 34  United States            Production
# 35  United States            Production
# 36  United States            Production
# 37  United States            Production
# 38  United States            Production
# 39  United States            Production
# 40  United States            Production
# 41  United States            Production
# 42  United States            Production
# 43  United States            Production
# 44  United States            Production
# 45  United States            Production
# 46  United States            Production
# 47  United States            Production
# 48  United States            Production
# 49  United States            Production
# 50  United States            Production
# 51  United States            Production
# 52  United States            Production
# 53  United States            Production
# 54  United States            Production
# 55  United States            Production
# 56  United States            Production
# 57  United States            Production
# 58  United States            Production
# 59  United States            Production
# 60  United States            Production
# 61            NaN                   NaN
# 62            NaN                   NaN
# 63            NaN                   NaN
#
#                                           Market_Year  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                 Year ending June 30
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                1964
# 7                                                1965
# 8                                                1966
# 9                                                1967
# 10                                               1968
# 11                                               1969
# 12                                               1970
# 13                                               1971
# 14                                               1972
# 15                                               1973
# 16                                               1974
# 17                                               1975
# 18                                               1976
# 19                                               1977
# 20                                               1978
# 21                                               1979
# 22                                               1980
# 23                                               1981
# 24                                               1982
# 25                                               1983
# 26                                               1984
# 27                                               1985
# 28                                               1986
# 29                                               1987
# 30                                               1988
# 31                                               1989
# 32                                               1990
# 33                                               1991
# 34                                               1992
# 35                                               1993
# 36                                               1994
# 37                                               1995
# 38                                               1996
# 39                                               1997
# 40                                               1998
# 41                                               1999
# 42                                               2000
# 43                                               2001
# 44                                               2002
# 45                                               2003
# 46                                               2004
# 47                                               2005
# 48                                               2006
# 49                                               2007
# 50                                               2008
# 51                                               2009
# 52                                               2010
# 53                                               2011
# 54                                               2012
# 55                                               2013
# 56                                               2014
# 57                                               2015
# 58                                               2016
# 59                                               2017
# 60                                               2018
# 61  NA = Not available. Source data cover selected...
# 62  1/ Estimates of plant nutrient use for other c...
# 63  Source: USDA, Economic Research Service using ...
#
#              Nitrogen_Use (1,000 nutrient short tons)  \
# 0                                                 NaN
# 1                                            Nitrogen
# 2                                                Corn
# 3                                                 NaN
# 4     --------------------------------------------...
# 5                                                 NaN
# 6                                          1622.53695
# 7                                            2150.643
# 8                                          2596.15811
# 9                                          3044.05368
# 10                                         3115.62784
# 11                                          3287.1036
# 12                                         3519.66832
# 13                                         3730.46191
# 14                                          3705.3552
# 15                                         3830.13153
# 16                                         3772.83335
# 17                                         3884.78265
# 18                                         5210.19786
# 19                                         5181.11232
# 20                                         4888.24875
# 21                                          5274.3312
# 22                                          5244.2832
# 23                                        5587.825165
# 24                                        5359.587075
# 25                                         3959.86992
# 26                                         5390.74299
# 27                                          5666.1192
# 28                                          4807.4598
# 29                                           4194.432
# 30                                        4499.456065
# 31                                        4601.040343
# 32                                         4748.42742
# 33                                         4715.03808
# 34                                          4886.9473
# 35                                        4368.833925
# 36                                         4603.15731
# 37                                          4158.1475
# 38                                         4828.57564
# 39                                         4792.08015
# 40                                         4845.51984
# 41                                         4649.81433
# 42                                         4908.50248
# 43                                        4249.302148
# 44                                         4719.72672
# 45                                         4710.14784
# 46                                        4792.052443
# 47                                               5023
# 48                                               4690
# 49                                               5714
# 50                                               5224
# 51                                        4875.136157
# 52                                          5610.2375
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                        6317.247191
# 57                                                NaN
# 58                                             6122.8
# 59                                                NaN
# 60                                            6003.65
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
#
#    Phosphate_Use (1,000 nutrient short tons)  \
# 0                                        NaN
# 1                                  Phosphate
# 2                                       Corn
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                 1052.50977
# 7                                  1336.0055
# 8                                 1626.16497
# 9                                  1857.1716
# 10                                1854.78848
# 11                                1789.10976
# 12                                2136.27285
# 13                                2023.60312
# 14                                 1993.6422
# 15                                1988.40256
# 16                                2101.90695
# 17                                1963.25186
# 18                                 2550.3282
# 19                                2523.09376
# 20                                 2415.9465
# 21                                2499.20277
# 22                                2412.87453
# 23                                2535.52455
# 24                                 2341.1102
# 25                                1695.71072
# 26                               2277.353325
# 27                                 2152.9584
# 28                                1964.38788
# 29                                  1675.853
# 30                               1855.784385
# 31                                1798.17503
# 32                                 1891.3605
# 33                                 1868.3946
# 34                                 1854.1758
# 35                                 1681.4756
# 36                                1740.39297
# 37                                  1495.746
# 38                                 1794.8787
# 39                                1782.78786
# 40                                1666.22832
# 41                                1579.66686
# 42                                1763.34858
# 43                                1552.26618
# 44                                 1700.9964
# 45                               1681.525665
# 46                               1728.869521
# 47                                      1781
# 48                                      1696
# 49                                      2066
# 50                                      1888
# 51                               1424.850547
# 52                                  1933.425
# 53                                       NA
# 54                                       NA
# 55                                       NA
# 56                               2287.640449
# 57                                       NaN
# 58                                   2081.05
# 59                                       NaN
# 60                                   2255.25
# 61                                       NaN
# 62                                       NaN
# 63                                       NaN
#
#    Potash_Use (1,000 nutrient short tons)
# 0                                     NaN
# 1                                  Potash
# 2                                    Corn
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                829.3698
# 7                              1204.36008
# 8                               1512.7116
# 9                               1750.4376
# 10                              1777.9398
# 11                             1765.33208
# 12                              2046.0078
# 13                             1946.45696
# 14                             1991.62842
# 15                              2051.9852
# 16                            2361.040825
# 17                             2162.41093
# 18                             2771.10288
# 19                             2835.10736
# 20                                2646.27
# 21                             2803.20936
# 22                             2927.21769
# 23                             3037.58364
# 24                             2956.67484
# 25                            2124.154675
# 26                             2872.96881
# 27                             2768.80464
# 28                              2330.8896
# 29                               2110.125
# 30                             2244.81855
# 31                               2195.991
# 32                             2398.69014
# 33                            2245.491315
# 34                              2256.4296
# 35                            2053.875575
# 36                              2118.9312
# 37                               1800.435
# 38                             2136.44282
# 39                             2171.51604
# 40                             2011.96512
# 41                            1936.055115
# 42                             1920.23799
# 43                            1888.324452
# 44                              2074.2108
# 45                              1962.5616
# 46                            2076.247217
# 47                                   1847
# 48                                   1901
# 49                                   2279
# 50                                   1687
# 51                            1457.241786
# 52                            1990.849375
# 53                                    NaN
# 54                                    NaN
# 55                                    NaN
# 56                            2407.752809
# 57                                    NaN
# 58                                2249.15
# 59                                    NaN
# 60                                2262.95
# 61                                    NaN
# 62                                    NaN
# 63                                    NaN

# %%
#It can be seen from the above table that the first 6 rows and the last 3 rows were not needed. So I dropped them. 

Fertilizer_Use_USA.drop(Fertilizer_Use_USA.tail(3).index, inplace = True)

Fertilizer_Use_USA.drop([0,1,2,3,4,5], axis=0, inplace=True)

# %%
#Checking datatypes 

Fertilizer_Use_USA.dtypes
# Out:
# Country_Name                                 object
# Attribute_Description                        object
# Market_Year                                  object
# Nitrogen_Use (1,000 nutrient short tons)     object
# Phosphate_Use (1,000 nutrient short tons)    object
# Potash_Use (1,000 nutrient short tons)       object
# dtype: object

# %%
#Datatypes were displayed as objects whereas they should be numeric. This neeeded to be fixed. 

Fertilizer_Use_USA[["Market_Year", "Nitrogen_Use (1,000 nutrient short tons)","Phosphate_Use (1,000 nutrient short tons)","Potash_Use (1,000 nutrient short tons)"]] = Fertilizer_Use_USA[["Market_Year", "Nitrogen_Use (1,000 nutrient short tons)","Phosphate_Use (1,000 nutrient short tons)","Potash_Use (1,000 nutrient short tons)"]].apply(pd.to_numeric,errors='coerce')

# %%
#Now the datatypes are correct 

Fertilizer_Use_USA.dtypes
# Out:
# Country_Name                                  object
# Attribute_Description                         object
# Market_Year                                    int64
# Nitrogen_Use (1,000 nutrient short tons)     float64
# Phosphate_Use (1,000 nutrient short tons)    float64
# Potash_Use (1,000 nutrient short tons)       float64
# dtype: object

# %%
#NA values were filled in with average values

Fertilizer_Use_USA.fillna(Fertilizer_Use_USA.mean(), inplace = True)

Fertilizer_Use_USA
# Out:
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/504097252.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Fertilizer_Use_USA.fillna(Fertilizer_Use_USA.mean(), inplace = True)
#      Country_Name Attribute_Description  Market_Year  \
# 6   United States            Production         1964
# 7   United States            Production         1965
# 8   United States            Production         1966
# 9   United States            Production         1967
# 10  United States            Production         1968
# 11  United States            Production         1969
# 12  United States            Production         1970
# 13  United States            Production         1971
# 14  United States            Production         1972
# 15  United States            Production         1973
# 16  United States            Production         1974
# 17  United States            Production         1975
# 18  United States            Production         1976
# 19  United States            Production         1977
# 20  United States            Production         1978
# 21  United States            Production         1979
# 22  United States            Production         1980
# 23  United States            Production         1981
# 24  United States            Production         1982
# 25  United States            Production         1983
# 26  United States            Production         1984
# 27  United States            Production         1985
# 28  United States            Production         1986
# 29  United States            Production         1987
# 30  United States            Production         1988
# 31  United States            Production         1989
# 32  United States            Production         1990
# 33  United States            Production         1991
# 34  United States            Production         1992
# 35  United States            Production         1993
# 36  United States            Production         1994
# 37  United States            Production         1995
# 38  United States            Production         1996
# 39  United States            Production         1997
# 40  United States            Production         1998
# 41  United States            Production         1999
# 42  United States            Production         2000
# 43  United States            Production         2001
# 44  United States            Production         2002
# 45  United States            Production         2003
# 46  United States            Production         2004
# 47  United States            Production         2005
# 48  United States            Production         2006
# 49  United States            Production         2007
# 50  United States            Production         2008
# 51  United States            Production         2009
# 52  United States            Production         2010
# 53  United States            Production         2011
# 54  United States            Production         2012
# 55  United States            Production         2013
# 56  United States            Production         2014
# 57  United States            Production         2015
# 58  United States            Production         2016
# 59  United States            Production         2017
# 60  United States            Production         2018
#
#     Nitrogen_Use (1,000 nutrient short tons)  \
# 6                                1622.536950
# 7                                2150.643000
# 8                                2596.158110
# 9                                3044.053680
# 10                               3115.627840
# 11                               3287.103600
# 12                               3519.668320
# 13                               3730.461910
# 14                               3705.355200
# 15                               3830.131530
# 16                               3772.833350
# 17                               3884.782650
# 18                               5210.197860
# 19                               5181.112320
# 20                               4888.248750
# 21                               5274.331200
# 22                               5244.283200
# 23                               5587.825165
# 24                               5359.587075
# 25                               3959.869920
# 26                               5390.742990
# 27                               5666.119200
# 28                               4807.459800
# 29                               4194.432000
# 30                               4499.456065
# 31                               4601.040343
# 32                               4748.427420
# 33                               4715.038080
# 34                               4886.947300
# 35                               4368.833925
# 36                               4603.157310
# 37                               4158.147500
# 38                               4828.575640
# 39                               4792.080150
# 40                               4845.519840
# 41                               4649.814330
# 42                               4908.502480
# 43                               4249.302148
# 44                               4719.726720
# 45                               4710.147840
# 46                               4792.052443
# 47                               5023.000000
# 48                               4690.000000
# 49                               5714.000000
# 50                               5224.000000
# 51                               4875.136157
# 52                               5610.237500
# 53                               4553.608120
# 54                               4553.608120
# 55                               4553.608120
# 56                               6317.247191
# 57                               4553.608120
# 58                               6122.800000
# 59                               4553.608120
# 60                               6003.650000
#
#     Phosphate_Use (1,000 nutrient short tons)  \
# 6                                 1052.509770
# 7                                 1336.005500
# 8                                 1626.164970
# 9                                 1857.171600
# 10                                1854.788480
# 11                                1789.109760
# 12                                2136.272850
# 13                                2023.603120
# 14                                1993.642200
# 15                                1988.402560
# 16                                2101.906950
# 17                                1963.251860
# 18                                2550.328200
# 19                                2523.093760
# 20                                2415.946500
# 21                                2499.202770
# 22                                2412.874530
# 23                                2535.524550
# 24                                2341.110200
# 25                                1695.710720
# 26                                2277.353325
# 27                                2152.958400
# 28                                1964.387880
# 29                                1675.853000
# 30                                1855.784385
# 31                                1798.175030
# 32                                1891.360500
# 33                                1868.394600
# 34                                1854.175800
# 35                                1681.475600
# 36                                1740.392970
# 37                                1495.746000
# 38                                1794.878700
# 39                                1782.787860
# 40                                1666.228320
# 41                                1579.666860
# 42                                1763.348580
# 43                                1552.266180
# 44                                1700.996400
# 45                                1681.525665
# 46                                1728.869521
# 47                                1781.000000
# 48                                1696.000000
# 49                                2066.000000
# 50                                1888.000000
# 51                                1424.850547
# 52                                1933.425000
# 53                                1912.329248
# 54                                1912.329248
# 55                                1912.329248
# 56                                2287.640449
# 57                                1912.329248
# 58                                2081.050000
# 59                                1912.329248
# 60                                2255.250000
#
#     Potash_Use (1,000 nutrient short tons)
# 6                               829.369800
# 7                              1204.360080
# 8                              1512.711600
# 9                              1750.437600
# 10                             1777.939800
# 11                             1765.332080
# 12                             2046.007800
# 13                             1946.456960
# 14                             1991.628420
# 15                             2051.985200
# 16                             2361.040825
# 17                             2162.410930
# 18                             2771.102880
# 19                             2835.107360
# 20                             2646.270000
# 21                             2803.209360
# 22                             2927.217690
# 23                             3037.583640
# 24                             2956.674840
# 25                             2124.154675
# 26                             2872.968810
# 27                             2768.804640
# 28                             2330.889600
# 29                             2110.125000
# 30                             2244.818550
# 31                             2195.991000
# 32                             2398.690140
# 33                             2245.491315
# 34                             2256.429600
# 35                             2053.875575
# 36                             2118.931200
# 37                             1800.435000
# 38                             2136.442820
# 39                             2171.516040
# 40                             2011.965120
# 41                             1936.055115
# 42                             1920.237990
# 43                             1888.324452
# 44                             2074.210800
# 45                             1962.561600
# 46                             2076.247217
# 47                             1847.000000
# 48                             1901.000000
# 49                             2279.000000
# 50                             1687.000000
# 51                             1457.241786
# 52                             1990.849375
# 53                             2143.159142
# 54                             2143.159142
# 55                             2143.159142
# 56                             2407.752809
# 57                             2143.159142
# 58                             2249.150000
# 59                             2143.159142
# 60                             2262.950000

# %%
#It was decided to create a column "Total_Annual_Fertilizer_Use_(MT)" which would be the sum of all three fertilizer types 

Fertilizer_Use_USA['Total_Annual_Fertilizer_Use (1,000 nutrient short tons)'] = Fertilizer_Use_USA.iloc[:, 3:6].sum(axis=1)

Fertilizer_Use_USA.head(5)
# Out:
#      Country_Name Attribute_Description  Market_Year  \
# 6   United States            Production         1964
# 7   United States            Production         1965
# 8   United States            Production         1966
# 9   United States            Production         1967
# 10  United States            Production         1968
#
#     Nitrogen_Use (1,000 nutrient short tons)  \
# 6                                 1622.53695
# 7                                 2150.64300
# 8                                 2596.15811
# 9                                 3044.05368
# 10                                3115.62784
#
#     Phosphate_Use (1,000 nutrient short tons)  \
# 6                                  1052.50977
# 7                                  1336.00550
# 8                                  1626.16497
# 9                                  1857.17160
# 10                                 1854.78848
#
#     Potash_Use (1,000 nutrient short tons)  \
# 6                                829.36980
# 7                               1204.36008
# 8                               1512.71160
# 9                               1750.43760
# 10                              1777.93980
#
#     Total_Annual_Fertilizer_Use (1,000 nutrient short tons)
# 6                                          3504.41652
# 7                                          4691.00858
# 8                                          5735.03468
# 9                                          6651.66288
# 10                                         6748.35612

# %% [markdown]
# 6.Combining Fertilizer_Use_USA With Grains_Pulses_Meals_USDA into New_Grains_Pulses_Meals_USDA

# %%
#Now the fertilizer table is ready to be added to "Grains_Pulses_Meals_USDA" 

New_Grains_Pulses_Meals_USDA = pd.merge(Grains_Pulses_Meals_USDA,Fertilizer_Use_USA,how="left", on = ["Market_Year", "Country_Name","Attribute_Description"])

New_Grains_Pulses_Meals_USDA
# Out:
#        Commodity_Description Country_Name  Market_Year Attribute_Description  \
# 0                Meal, Copra    Australia         1964      Beginning Stocks
# 1                Meal, Copra    Australia         1964  Domestic Consumption
# 2                Meal, Copra    Australia         1964         Ending Stocks
# 3                Meal, Copra    Australia         1964               Exports
# 4                Meal, Copra    Australia         1964               Imports
# ...                      ...          ...          ...                   ...
# 289185          Rice, Milled      Jamaica         2013            Production
# 289186          Rice, Milled      Jamaica         2013    Total Distribution
# 289187          Rice, Milled      Jamaica         2013          Total Supply
# 289188          Rice, Milled      Jamaica         2014      Beginning Stocks
# 289189          Rice, Milled      Jamaica         2014  Domestic Consumption
#
#         Volume  Average_Production_2000_2022 Above_Or_Below_Average  \
# 0            0                           NaN                    NaN
# 1        11000                           NaN                    NaN
# 2            0                           NaN                    NaN
# 3            0                           NaN                    NaN
# 4            0                           NaN                    NaN
# ...        ...                           ...                    ...
# 289185       0                           NaN                    NaN
# 289186   82000                           NaN                    NaN
# 289187   82000                           NaN                    NaN
# 289188       0                           NaN                    NaN
# 289189   89000                           NaN                    NaN
#
#         Annual_Precipitation  Nitrogen_Use (1,000 nutrient short tons)  \
# 0                        NaN                                       NaN
# 1                        NaN                                       NaN
# 2                        NaN                                       NaN
# 3                        NaN                                       NaN
# 4                        NaN                                       NaN
# ...                      ...                                       ...
# 289185                   NaN                                       NaN
# 289186                   NaN                                       NaN
# 289187                   NaN                                       NaN
# 289188                   NaN                                       NaN
# 289189                   NaN                                       NaN
#
#         Phosphate_Use (1,000 nutrient short tons)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 289185                                        NaN
# 289186                                        NaN
# 289187                                        NaN
# 289188                                        NaN
# 289189                                        NaN
#
#         Potash_Use (1,000 nutrient short tons)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 289185                                     NaN
# 289186                                     NaN
# 289187                                     NaN
# 289188                                     NaN
# 289189                                     NaN
#
#         Total_Annual_Fertilizer_Use (1,000 nutrient short tons)
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 289185                                                NaN
# 289186                                                NaN
# 289187                                                NaN
# 289188                                                NaN
# 289189                                                NaN
#
# [289190 rows x 12 columns]

# %% [markdown]
# 7.New_Grains_Pulses_Meals_USDA: Statistical Analysis

# %%
#Data Normalization before using regression. 

New_Grains_Pulses_Meals_USDA['Annual_Precipitation'] = (New_Grains_Pulses_Meals_USDA['Annual_Precipitation'] - New_Grains_Pulses_Meals_USDA['Annual_Precipitation'].min())/(New_Grains_Pulses_Meals_USDA['Annual_Precipitation'].max() - New_Grains_Pulses_Meals_USDA['Annual_Precipitation'].min())

New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'] = (New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'] - New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'].min())/(New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'].max() - New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'].min())

New_Grains_Pulses_Meals_USDA['Volume'] = (New_Grains_Pulses_Meals_USDA['Volume'] - New_Grains_Pulses_Meals_USDA['Volume'].min())/(New_Grains_Pulses_Meals_USDA['Volume'].max() - New_Grains_Pulses_Meals_USDA['Volume'].min())

New_Grains_Pulses_Meals_USDA.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_Annual_Fertilizer_Use_(MT)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/2831914142.py in <module>
#       3 New_Grains_Pulses_Meals_USDA['Annual_Precipitation'] = (New_Grains_Pulses_Meals_USDA['Annual_Precipitation'] - New_Grains_Pulses_Meals_USDA['Annual_Precipitation'].min())/(New_Grains_Pulses_Meals_USDA['Annual_Precipitation'].max() - New_Grains_Pulses_Meals_USDA['Annual_Precipitation'].min())
#       4
# ----> 5 New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'] = (New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'] - New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'].min())/(New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'].max() - New_Grains_Pulses_Meals_USDA['Total_Annual_Fertilizer_Use_(MT)'].min())
#       6
#       7 New_Grains_Pulses_Meals_USDA['Volume'] = (New_Grains_Pulses_Meals_USDA['Volume'] - New_Grains_Pulses_Meals_USDA['Volume'].min())/(New_Grains_Pulses_Meals_USDA['Volume'].max() - New_Grains_Pulses_Meals_USDA['Volume'].min())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Total_Annual_Fertilizer_Use_(MT)'

# %%
# Annual_Precipiration should be in inches

# %%
#creating subtable for US and corn and production 

US_Corn_Production = New_Grains_Pulses_Meals_USDA.loc[(New_Grains_Pulses_Meals_USDA['Country_Name'] == 'United States') & (New_Grains_Pulses_Meals_USDA['Attribute_Description'] == 'Production') & (New_Grains_Pulses_Meals_USDA['Commodity_Description'] == 'Corn')]

US_Corn_Production.head(10)
# Out:
#       Commodity_Description   Country_Name  Market_Year Attribute_Description  \
# 2429                   Corn  United States         1964            Production
# 5949                   Corn  United States         1965            Production
# 9461                   Corn  United States         1966            Production
# 13013                  Corn  United States         1967            Production
# 16589                  Corn  United States         1968            Production
# 20645                  Corn  United States         1969            Production
# 24717                  Corn  United States         1970            Production
# 28821                  Corn  United States         1971            Production
# 33493                  Corn  United States         1972            Production
# 38197                  Corn  United States         1973            Production
#
#          Volume Unit_Description  Average_Production_2000_2022  \
# 2429   0.182278              NaN                           NaN
# 5949   0.214642              NaN                           NaN
# 9461   0.218028              NaN                           NaN
# 13013  0.254269              NaN                           NaN
# 16589  0.232778              NaN                           NaN
# 20645  0.245203              NaN                           NaN
# 24717  0.217224              NaN                           NaN
# 28821  0.295384              NaN                           NaN
# 33493  0.291908              NaN                           NaN
# 38197  0.296663              NaN                           NaN
#
#       Above_Or_Below_Average  Annual_Precipitation  \
# 2429                     NaN              0.444444
# 5949                     NaN              0.444444
# 9461                     NaN              0.111111
# 13013                    NaN              0.444444
# 16589                    NaN              0.444444
# 20645                    NaN              0.555556
# 24717                    NaN              0.444444
# 28821                    NaN              0.444444
# 33493                    NaN              0.666667
# 38197                    NaN              1.000000
#
#        Nitrogen_Use (1,000 nutrient short tons)  \
# 2429                                 1622.53695
# 5949                                 2150.64300
# 9461                                 2596.15811
# 13013                                3044.05368
# 16589                                3115.62784
# 20645                                3287.10360
# 24717                                3519.66832
# 28821                                3730.46191
# 33493                                3705.35520
# 38197                                3830.13153
#
#        Phosphate_Use (1,000 nutrient short tons)  \
# 2429                                  1052.50977
# 5949                                  1336.00550
# 9461                                  1626.16497
# 13013                                 1857.17160
# 16589                                 1854.78848
# 20645                                 1789.10976
# 24717                                 2136.27285
# 28821                                 2023.60312
# 33493                                 1993.64220
# 38197                                 1988.40256
#
#        Potash_Use (1,000 nutrient short tons)  \
# 2429                                829.36980
# 5949                               1204.36008
# 9461                               1512.71160
# 13013                              1750.43760
# 16589                              1777.93980
# 20645                              1765.33208
# 24717                              2046.00780
# 28821                              1946.45696
# 33493                              1991.62842
# 38197                              2051.98520
#
#        Total_Annual_Fertilizer_Use_(MT)  \
# 2429                           0.000000
# 5949                           0.154978
# 9461                           0.291336
# 13013                          0.411055
# 16589                          0.423683
# 20645                          0.435855
# 24717                          0.548230
# 28821                          0.548044
# 33493                          0.546751
# 38197                          0.570247
#
#        Total_Annual_Fertilizer_Use (1,000 nutrient short tons)
# 2429                                          3504.41652
# 5949                                          4691.00858
# 9461                                          5735.03468
# 13013                                         6651.66288
# 16589                                         6748.35612
# 20645                                         6841.54544
# 24717                                         7701.94897
# 28821                                         7700.52199
# 33493                                         7690.62582
# 38197                                         7870.51929

# %%
##Using multiple linear regression to check the correlation 

Z = US_Corn_Production[['Annual_Precipitation','Total_Annual_Fertilizer_Use_(MT)']]

from sklearn.linear_model import LinearRegression

lm =LinearRegression()

Y = US_Corn_Production['Volume']

lm.fit(Z,Y)

Yhat=lm.predict(Z)

Yhat

#using distribution plot to compare the fitted values that result from the model and the actual values 

ax1 = sns.distplot(US_Corn_Production['Volume'],hist=False,color='r',label='Actual Value')

sns.distplot(Yhat,hist=False,color='b',label='Fitted Values',ax=ax1)

#Marks on plot
# Out:
# /Users/germankosenkov/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/germankosenkov/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Volume', ylabel='Density'>

# %%
#the results are not impressive 

import matplotlib.pyplot as plt

# %%
#ScatterPlot - normally predictor on x 

y = US_Corn_Production['Volume']
x = US_Corn_Production['Annual_Precipitation']
plt.scatter(x,y)

plt.title("Production Vs Precipitation")
plt.xlabel("Precipitation Volume")
plt.ylabel("Production Volume")
# Out:
# Text(0, 0.5, 'Production Volume')

# %%
sns.regplot(x = 'Annual_Precipitation', y = 'Volume',data = US_Corn_Production)
plt.ylim(0,)
# Out:
# (0.0, 0.8229773202840526)

# %%
#model evaluation using vizualization 

sns.regplot(x = 'Total_Annual_Fertilizer_Use_(MT)', y = 'Volume',data = US_Corn_Production)
plt.ylim(0,)
# Out:
# (0.0, 0.8291525615542052)

# %%
#Linear Regression - testing the fit 

from sklearn.linear_model import LinearRegression

lm =LinearRegression()
X = US_Corn_Production[['Total_Annual_Fertilizer_Use_(MT)']]
Y = US_Corn_Production['Volume']

lm.fit(X,Y)

Yhat=lm.predict(X)

Yhat

ax1 = sns.distplot(US_Corn_Production['Volume'],hist=False,color='r',label='Actual Value')

sns.distplot(Yhat,hist=False,color='b',label='Fitted Values',ax=ax1)
# Out:
# /Users/germankosenkov/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/germankosenkov/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Volume', ylabel='Density'>

# %%
#Pearson correlation 
# Correlation coefficient - Close to +1: Large Positive, Close to -1: large negative, close to 0: no relationship
#P-value: P-value<0.001 strong certainty , P<0.05 - moderate, P< 0.1 Weak, P>0.1 no certainty\

import scipy 

from scipy import stats

pearson_coef,p_value = stats.pearsonr(US_Data_Final['Value'],US_Data_Final['total_ferts_used'])

pearson_coef,p_value

#perfect positive correlation

#conclusion: Moderate degree: If the value lies between ± 0.30 and ± 0.49, then it is said to be a medium correlation. good certainty.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qs/26crv4l161g4k3cvlckx2s5h0000gn/T/ipykernel_25187/2011845741.py in <module>
#       7 from scipy import stats
#       8
# ----> 9 pearson_coef,p_value = stats.pearsonr(US_Data_Final['Value'],US_Data_Final['total_ferts_used'])
#      10
#      11 pearson_coef,p_value
#
# NameError: name 'US_Data_Final' is not defined

# %%
#pearson for precipitation - to measure the strength of the correlation 
#interpretation: close to +1 - Large positive relationship
#Close to -1 large negative
#closde to 0: No relationship




pearson_coef,p_value = stats.pearsonr(US_Data_Final['Value'],US_Data_Final['Precipitation'])

pearson_coef,p_value

#low correlation and no certainty based on p value

# %% [markdown]
# 8.Conclusions

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(Z,Y,test_size=0.3,random_state=0)

x_train,x_test,y_train,y_test
# Out:
# (        Annual_Precipitation  Total_Annual_Fertilizer_Use_(MT)
#  28821               0.444444                          0.548044
#  62877               0.444444                          0.841904
#  128249              0.333333                          0.651800
#  167753              0.555556                          0.787577
#  245155              0.000000                          0.665530
#  83249               0.777778                          0.600765
#  256675              0.666667                          0.722791
#  162761              0.666667                          0.555450
#  68009               0.777778                          0.923700
#  20645               0.555556                          0.435855
#  137833              0.777778                          0.665153
#  73169               0.222222                          0.924697
#  261643              0.666667                          0.695422
#  93553               0.777778                          0.515889
#  233867              0.555556                          0.731184
#  33493               0.666667                          0.546751
#  57797               0.444444                          0.918812
#  118721              0.222222                          0.664489
#  78337               0.444444                          1.000000
#  197843              0.555556                          0.907538
#  266683              0.555556                          0.717446
#  182769              0.555556                          0.666710
#  5949                0.444444                          0.154978
#  52805               0.000000                          0.917808
#  202907              0.666667                          0.666710
#  113993              0.222222                          0.608778
#  24717               0.444444                          0.548230
#  109145              0.888889                          0.655559
#  172753              0.444444                          0.666710
#  98721               0.888889                          0.686406
#  88377               0.555556                          0.647561
#  38197               1.000000                          0.570247
#  187777              0.555556                          0.980632
#  250891              0.333333                          0.664896
#  13013               0.444444                          0.411055
#  2429                0.444444                          0.000000
#  228675              0.444444                          0.925155
#  213115              0.888889                          0.934231,
#          Annual_Precipitation  Total_Annual_Fertilizer_Use_(MT)
#  218315              1.000000                          0.558390
#  157769              0.555556                          0.691513
#  192779              1.000000                          0.666710
#  123489              0.333333                          0.546655
#  47845               0.777778                          0.588522
#  9461                0.111111                          0.291336
#  152785              0.333333                          0.856079
#  207955              1.000000                          0.916531
#  223483              0.555556                          0.919040
#  142817              0.444444                          0.672183
#  16589               0.444444                          0.423683
#  42965               0.555556                          0.617953
#  133033              0.555556                          0.633424
#  103889              0.666667                          0.684641
#  147801              0.444444                          0.624642
#  239467              0.333333                          0.584599
#  177761              0.222222                          0.666710,
#  28821     0.295384
#  62877     0.380221
#  128249    0.469097
#  167753    0.650030
#  245155    0.257843
#  83249     0.331558
#  256675    0.415068
#  162761    0.683606
#  68009     0.414760
#  20645     0.245203
#  137833    0.617608
#  73169     0.347338
#  261643    0.391042
#  93553     0.387133
#  233867    0.430330
#  33493     0.291908
#  57797     0.340311
#  118721    0.518705
#  78337     0.424726
#  197843    0.792468
#  266683    0.495772
#  182769    0.723551
#  5949      0.214642
#  52805     0.329017
#  202907    0.764289
#  113993    0.493362
#  24717     0.217224
#  109145    0.510524
#  172753    0.644203
#  98721     0.483001
#  88377     0.525792
#  38197     0.296663
#  187777    0.743776
#  250891    0.394032
#  13013     0.254269
#  2429      0.182278
#  228675    0.464318
#  213115    0.430818
#  Name: Volume, dtype: float64,
#  218315    0.218376
#  157769    0.630038
#  192779    0.711585
#  123489    0.497127
#  47845     0.305558
#  9461      0.218028
#  152785    0.682074
#  207955    0.750214
#  223483    0.401366
#  142817    0.581334
#  16589     0.232778
#  42965     0.245953
#  133033    0.527715
#  103889    0.481654
#  147801    0.550935
#  239467    0.373072
#  177761    0.562651
#  Name: Volume, dtype: float64)

# %%
##Using multiple linear regression to check the correlation 

Z = US_Corn_Production[['Annual_Precipitation','Total_Annual_Fertilizer_Use_(MT)']]

from sklearn.linear_model import LinearRegression

lm =LinearRegression()

Y = US_Corn_Production['Volume']

lm.fit(Z,Y)

Yhat=lm.predict(Z)

Yhat

ax1 = sns.distplot(US_Corn_Production['Volume'],hist=False,color='r',label='Actual Value')

sns.distplot(Yhat,hist=False,color='b',label='Fitted Values',ax=ax1)

#Marks on plot




#training and predicting vALUES

lm.fit(Z,Y)

lm.predict(np.array)
